# %%
import torch
import matplotlib.pyplot as plt

# Load the metrics
metrics = torch.load('./test_results/anomaly_detection_WADI_Informer_WADI_ftM_sl100_ll48_pl0_dm128_nh8_el1_dl1_df128_expand2_dc4_fc1_ebtimeF_dtTrue_test_0/metrics_2024-06-26_11-46.pth')

# Extract epochs and loss values
#epochs = metrics['epoch']
iters = metrics['iters']
losses = metrics['loss']

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(iters, losses, marker='o', linestyle='-', color='b', label='Training Loss')
plt.title('Training Loss per Iteration')
plt.xlabel('Iters')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
